# %%
from helpers import *

# %%
def f(x, y):
    return (-2*y, x)

# %%
plot_vector_field(f, -5, 5, -5, 5)

# %%
def f(x, y):
    return (-x, -y)

plot_vector_field(f, -5, 5, -5, 5)

# %%
def u(x,y):
    return 0.5 * (x**2 + y**2)

# %%
plot_scalar_field(u, -5, 5, -5, 5)

# %% [markdown]
# ### 11.4.2　将标量场绘制成热图

# %%
scalar_field_heatmap(u, -5, 5, -5, 5)

# %% [markdown]
# ### 11.4.3　将标量场绘制成等高线图

# %%
scalar_field_contour(u, -10, 10, -10, 10, levels=[10,20,30,40,50,60])

# %%
def v(x, y):
    return 1 + y**2 - 2*x**2 + x**6

# %%
plot_scalar_field(v, -1.5, 1.5, -1.5, 1.5)

# %% [markdown]
# ### 11.5.4　用势能的梯度计算力场

# %%
def f(x, y):
    return (4*x - 6*x**5, -2*y)

# %%
plot_vector_field(f, -1.1, 1.2, -3, 3, 0.3, 0.3)

# %% [markdown]
# 练习11.4：绘制$h(x,y) = e^y sin(x)$的横截面，其中$y=1$。然后绘制$h(x,y)$的横截面，其中$x=\pi/6$。

# %% [markdown]
# $y=1$时： $h(x,y) = esin(x)$
#
# $x = \pi/6$时：$h(x,y) = e^ysin(\pi/6)$

# %%
import math
def f1(x):
    return math.e * math.sin(x)

def f2(y):
    return math.e ** y * math.sin(math.pi / 6)

# %%
from helpers import *

# %%
plot_function(f1,-3, 3)

# %%
plot_function(f2, -3, 3)
