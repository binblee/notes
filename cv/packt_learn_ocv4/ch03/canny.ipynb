# %%
import cv2
import numpy as np
from plt_utils import plt_imgshow

# %% [markdown]
# 边缘检测 edge detection

# %%
img = cv2.imread('../images/statue_small.jpg',0)
canny_img = cv2.Canny(img, 200, 300)
plt_imgshow(canny_img)
