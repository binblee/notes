# %%
import cv2
from plt_utils import plt_imgshow

# %%
#  
face_cascade = cv2.CascadeClassifier(f'{cv2.data.haarcascades}haarcascade_frontalface_default.xml')

# %%
img = cv2.imread('../images/woodcutters.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt_imgshow(img)

# %%
faces = face_cascade.detectMultiScale(gray, 1.08, 5)
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0), 2)

# %%
plt_imgshow(img)

# %%
print(f'{cv2.data.haarcascades}haarcascade_frontalface_default.xml')
# Out:
# /Users/libin/.virtualenvs/cv/lib/python3.11/site-packages/cv2/data/haarcascade_frontalface_default.xml
